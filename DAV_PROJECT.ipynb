# %% [markdown]
# <a href="https://colab.research.google.com/github/varshini1028/dav_project/blob/main/DAV_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IMPORTING LIBRARIES AND CSV FILE

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('IMDB Top 250 Movies.csv')

# %% [markdown]
# #1.DISPLAY TOP 10 ROWS OFTHE DATASET

# %%
data.head(10)
# Out:
#    rank                                               name  year  rating  \
# 0     1                           The Shawshank Redemption  1994     9.3
# 1     2                                      The Godfather  1972     9.2
# 2     3                                    The Dark Knight  2008     9.0
# 3     4                              The Godfather Part II  1974     9.0
# 4     5                                       12 Angry Men  1957     9.0
# 5     6                                   Schindler's List  1993     9.0
# 6     7      The Lord of the Rings: The Return of the King  2003     9.0
# 7     8                                       Pulp Fiction  1994     8.9
# 8     9  The Lord of the Rings: The Fellowship of the Ring  2001     8.8
# 9    10                     The Good, the Bad and the Ugly  1966     8.8
#
#                      genre certificate run_time  \
# 0                    Drama           R   2h 22m
# 1              Crime,Drama           R   2h 55m
# 2       Action,Crime,Drama       PG-13   2h 32m
# 3              Crime,Drama           R   3h 22m
# 4              Crime,Drama    Approved   1h 36m
# 5  Biography,Drama,History           R   3h 15m
# 6   Action,Adventure,Drama       PG-13   3h 21m
# 7              Crime,Drama           R   2h 34m
# 8   Action,Adventure,Drama       PG-13   2h 58m
# 9        Adventure,Western    Approved   2h 58m
#
#                                              tagline     budget  box_office  \
# 0  Fear can hold you prisoner. Hope can set you f...   25000000    28884504
# 1                         An offer you can't refuse.    6000000   250341816
# 2                                    Why So Serious?  185000000  1006234167
# 3       All the power on earth can't change destiny.   13000000    47961919
# 4  Life Is In Their Hands -- Death Is On Their Mi...     350000         955
# 5    Whoever saves one life, saves the world entire.   22000000   322161245
# 6                    The eye of the enemy is moving.   94000000  1146457748
# 7  Girls like me don't make invitations like this...    8000000   213928762
# 8                           The Legend Comes to Life   93000000   898204420
# 9  They formed an alliance of hate to steal a for...    1200000    25253887
#
#                                                casts             directors  \
# 0  Tim Robbins,Morgan Freeman,Bob Gunton,William ...        Frank Darabont
# 1  Marlon Brando,Al Pacino,James Caan,Diane Keato...  Francis Ford Coppola
# 2  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...     Christopher Nolan
# 3  Al Pacino,Robert De Niro,Robert Duvall,Diane K...  Francis Ford Coppola
# 4  Henry Fonda,Lee J. Cobb,Martin Balsam,John Fie...          Sidney Lumet
# 5  Liam Neeson,Ralph Fiennes,Ben Kingsley,Carolin...      Steven Spielberg
# 6  Elijah Wood,Viggo Mortensen,Ian McKellen,Orlan...         Peter Jackson
# 7  John Travolta,Uma Thurman,Samuel L. Jackson,Br...     Quentin Tarantino
# 8  Elijah Wood,Ian McKellen,Orlando Bloom,Sean Be...         Peter Jackson
# 9  Clint Eastwood,Eli Wallach,Lee Van Cleef,Aldo ...          Sergio Leone
#
#                                             writers
# 0                       Stephen King,Frank Darabont
# 1                   Mario Puzo,Francis Ford Coppola
# 2   Jonathan Nolan,Christopher Nolan,David S. Goyer
# 3                   Francis Ford Coppola,Mario Puzo
# 4                                     Reginald Rose
# 5                   Thomas Keneally,Steven Zaillian
# 6         J.R.R. Tolkien,Fran Walsh,Philippa Boyens
# 7                     Quentin Tarantino,Roger Avary
# 8         J.R.R. Tolkien,Fran Walsh,Philippa Boyens
# 9  Luciano Vincenzoni,Sergio Leone,Agenore Incrocci

# %% [markdown]
# #2.CHECK LAST 10 ROWS OFTHE DATASET

# %%
data.tail(10)
# Out:
#      rank                   name  year  rating                       genre  \
# 240   241     The Sound of Music  1965     8.1      Biography,Drama,Family
# 241   242  It Happened One Night  1934     8.1              Comedy,Romance
# 242   243                Persona  1966     8.1              Drama,Thriller
# 243   244          Life of Brian  1979     8.0                      Comedy
# 244   245         The Iron Giant  1999     8.1  Animation,Action,Adventure
# 245   246               The Help  2011     8.1                       Drama
# 246   247            Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                 Gandhi  1982     8.0     Biography,Drama,History
# 249   250     Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
#     certificate run_time                                            tagline  \
# 240           G   2h 52m  RADIANCE THAT FLOODS THE SCREEN...AND WARMS TH...
# 241      Passed   1h 45m  Two great lovers of the screen in the grandest...
# 242   Not Rated   1h 23m                       A new film by Ingmar Bergman
# 243           R   1h 34m  A motion picture destined to offend nearly two...
# 244          PG   1h 26m                  Some secrets are too huge to hide
# 245       PG-13   2h 26m                      Change begins with a whisper.
# 246           G   2h 22m  There is man and beast at nature's mercy. Ther...
# 247           G   1h 30m                     Wish granted! (DVD re-release)
# 248          PG   3h 11m             His Triumph Changed The World Forever.
# 249       PG-13    3h 1m  Inside everyone is a frontier waiting to be di...
#
#             budget     box_office  \
# 240        8200000      159428329
# 241         325000          11477
# 242  Not Available  Not Available
# 243        4000000       20745728
# 244       70000000       23335817
# 245       25000000      216639112
# 246        4000000          14480
# 247  Not Available  Not Available
# 248       22000000       52767889
# 249       22000000      424208848
#
#                                                  casts  \
# 240  Julie Andrews,Christopher Plummer,Eleanor Park...
# 241  Clark Gable,Claudette Colbert,Walter Connolly,...
# 242  Bibi Andersson,Liv Ullmann,Margaretha Krook,Gu...
# 243  Graham Chapman,John Cleese,Michael Palin,Terry...
# 244  Eli Marienthal,Harry Connick Jr.,Jennifer Anis...
# 245  Viola Davis,Emma Stone,Octavia Spencer,Bryce D...
# 246  Maksim Munzuk,Yuriy Solomin,Mikhail Bychkov,Vl...
# 247  Scott Weinger,Robin Williams,Linda Larkin,Jona...
# 248  Ben Kingsley,John Gielgud,Rohini Hattangadi,Ro...
# 249  Kevin Costner,Mary McDonnell,Graham Greene,Rod...
#
#                     directors                                        writers
# 240               Robert Wise    Georg Hurdalek,Howard Lindsay,Russel Crouse
# 241               Frank Capra             Robert Riskin,Samuel Hopkins Adams
# 242            Ingmar Bergman                                 Ingmar Bergman
# 243               Terry Jones       Graham Chapman,John Cleese,Terry Gilliam
# 244                 Brad Bird             Tim McCanlies,Brad Bird,Ted Hughes
# 245               Tate Taylor                   Tate Taylor,Kathryn Stockett
# 246            Akira Kurosawa  Akira Kurosawa,Yuriy Nagibin,Vladimir Arsenev
# 247  Ron Clements,John Musker           Ron Clements,John Musker,Ted Elliott
# 248      Richard Attenborough                                    John Briley
# 249             Kevin Costner                                  Michael Blake

# %% [markdown]
# #3.FIND SHAPE OF OUR DATASET(Number of Rows and Number of Columns)

# %%
data.shape
# Out:
# (250, 13)

# %% [markdown]
# #4.Getting Information about our dataset like total number of rows,total number of columns,datatypes of each column and memory requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         250 non-null    int64
#  1   name         250 non-null    object
#  2   year         250 non-null    int64
#  3   rating       250 non-null    float64
#  4   genre        250 non-null    object
#  5   certificate  250 non-null    object
#  6   run_time     250 non-null    object
#  7   tagline      250 non-null    object
#  8   budget       250 non-null    object
#  9   box_office   250 non-null    object
#  10  casts        250 non-null    object
#  11  directors    250 non-null    object
#  12  writers      250 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 25.5+ KB

# %% [markdown]
# #5.check missing values in the dataset

# %%
print("Any missing value?", data.isnull().values.any())
# Out:
# Any missing value? True

# %%
data.isnull()
# Out:
#       rank   name   year  rating  genre  certificate  run_time  tagline  \
# 0    False  False  False   False  False        False     False    False
# 1    False  False  False   False  False        False     False    False
# 2    False  False  False   False  False        False     False    False
# 3    False  False  False   False  False        False     False    False
# 4    False  False  False   False  False        False     False    False
# ..     ...    ...    ...     ...    ...          ...       ...      ...
# 245  False  False  False   False  False        False     False    False
# 246  False  False  False   False  False        False     False    False
# 247  False  False  False   False  False        False     False    False
# 248  False  False  False   False  False        False     False    False
# 249  False  False  False   False  False        False     False    False
#
#      budget  box_office  casts  directors  writers
# 0     False       False  False      False    False
# 1     False        True  False      False    False
# 2     False       False  False      False    False
# 3     False       False  False      False    False
# 4     False       False  False      False    False
# ..      ...         ...    ...        ...      ...
# 245   False       False  False      False    False
# 246   False       False  False      False    False
# 247   False       False  False      False    False
# 248   False       False  False      False    False
# 249   False       False  False      False    False
#
# [250 rows x 13 columns]

# %%
data.isnull().sum()
# Out:
# rank           0
# name           0
# year           0
# rating         0
# genre          0
# certificate    0
# run_time       1
# tagline        1
# budget         1
# box_office     2
# casts          0
# directors      2
# writers        0
# dtype: int64

# %%
per_missing = data.isnull().sum()*100/len(data)
per_missing
# Out:
# rank           0.0
# name           0.0
# year           0.0
# rating         0.0
# genre          0.0
# certificate    0.0
# run_time       0.4
# tagline        0.4
# budget         0.4
# box_office     0.8
# casts          0.0
# directors      0.8
# writers        0.0
# dtype: float64

# %% [markdown]
# #6.Drop All The Missing Values

# %%
data.dropna(axis=0)
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# 5       6          Schindler's List  1993     9.0     Biography,Drama,History
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
#     certificate run_time                                            tagline  \
# 0             R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 2         PG-13   2h 32m                                    Why So Serious?
# 3             R   3h 22m       All the power on earth can't change destiny.
# 4      Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
# 5             R   3h 15m    Whoever saves one life, saves the world entire.
# ..          ...      ...                                                ...
# 245       PG-13   2h 26m                      Change begins with a whisper.
# 246           G   2h 22m  There is man and beast at nature's mercy. Ther...
# 247           G   1h 30m                     Wish granted! (DVD re-release)
# 248          PG   3h 11m             His Triumph Changed The World Forever.
# 249       PG-13    3h 1m  Inside everyone is a frontier waiting to be di...
#
#             budget     box_office  \
# 0         25000000       28884504
# 2        185000000     1006234167
# 3         13000000       47961919
# 4           350000            955
# 5         22000000      322161245
# ..             ...            ...
# 245       25000000      216639112
# 246        4000000          14480
# 247  Not Available  Not Available
# 248       22000000       52767889
# 249       22000000      424208848
#
#                                                  casts  \
# 0    Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# 2    Christian Bale,Heath Ledger,Aaron Eckhart,Mich...
# 3    Al Pacino,Robert De Niro,Robert Duvall,Diane K...
# 4    Henry Fonda,Lee J. Cobb,Martin Balsam,John Fie...
# 5    Liam Neeson,Ralph Fiennes,Ben Kingsley,Carolin...
# ..                                                 ...
# 245  Viola Davis,Emma Stone,Octavia Spencer,Bryce D...
# 246  Maksim Munzuk,Yuriy Solomin,Mikhail Bychkov,Vl...
# 247  Scott Weinger,Robin Williams,Linda Larkin,Jona...
# 248  Ben Kingsley,John Gielgud,Rohini Hattangadi,Ro...
# 249  Kevin Costner,Mary McDonnell,Graham Greene,Rod...
#
#                     directors                                          writers
# 0              Frank Darabont                      Stephen King,Frank Darabont
# 2           Christopher Nolan  Jonathan Nolan,Christopher Nolan,David S. Goyer
# 3        Francis Ford Coppola                  Francis Ford Coppola,Mario Puzo
# 4                Sidney Lumet                                    Reginald Rose
# 5            Steven Spielberg                  Thomas Keneally,Steven Zaillian
# ..                        ...                                              ...
# 245               Tate Taylor                     Tate Taylor,Kathryn Stockett
# 246            Akira Kurosawa    Akira Kurosawa,Yuriy Nagibin,Vladimir Arsenev
# 247  Ron Clements,John Musker             Ron Clements,John Musker,Ted Elliott
# 248      Richard Attenborough                                      John Briley
# 249             Kevin Costner                                    Michael Blake
#
# [244 rows x 13 columns]

# %% [markdown]
# #7.Check For Duplicate Data

# %%
dup_data = data.duplicated().any()

# %%
print("Are there any duplicate  values :", dup_data)
# Out:
# Are there any duplicate  values : False

# %% [markdown]
# #8.Get overall statistics about the DataFrame

# %%
data.describe()
# Out:
#              rank         year      rating
# count  250.000000   250.000000  250.000000
# mean   125.500000  1986.360000    8.307200
# std     72.312977    25.125356    0.229081
# min      1.000000  1921.000000    8.000000
# 25%     63.250000  1966.250000    8.100000
# 50%    125.500000  1994.000000    8.200000
# 75%    187.750000  2006.000000    8.400000
# max    250.000000  2022.000000    9.300000

# %%
data.describe(include='all')
# Out:
#               rank                      name         year      rating  genre  \
# count   250.000000                       250   250.000000  250.000000    250
# unique         NaN                       250          NaN         NaN    104
# top            NaN  The Shawshank Redemption          NaN         NaN  Drama
# freq           NaN                         1          NaN         NaN     19
# mean    125.500000                       NaN  1986.360000    8.307200    NaN
# std      72.312977                       NaN    25.125356    0.229081    NaN
# min       1.000000                       NaN  1921.000000    8.000000    NaN
# 25%      63.250000                       NaN  1966.250000    8.100000    NaN
# 50%     125.500000                       NaN  1994.000000    8.200000    NaN
# 75%     187.750000                       NaN  2006.000000    8.400000    NaN
# max     250.000000                       NaN  2022.000000    9.300000    NaN
#
#        certificate run_time  \
# count          250      249
# unique          15      102
# top              R   2h 10m
# freq            97        9
# mean           NaN      NaN
# std            NaN      NaN
# min            NaN      NaN
# 25%            NaN      NaN
# 50%            NaN      NaN
# 75%            NaN      NaN
# max            NaN      NaN
#
#                                                   tagline         budget  \
# count                                                 249            249
# unique                                                249            127
# top     Fear can hold you prisoner. Hope can set you f...  Not Available
# freq                                                    1             39
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#            box_office                                              casts  \
# count             248                                                250
# unique            219                                                250
# top     Not Available  Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# freq               30                                                  1
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN
#
#               directors          writers
# count               248              250
# unique              159              233
# top     Martin Scorsese  Charles Chaplin
# freq                  7                4
# mean                NaN              NaN
# std                 NaN              NaN
# min                 NaN              NaN
# 25%                 NaN              NaN
# 50%                 NaN              NaN
# 75%                 NaN              NaN
# max                 NaN              NaN

# %% [markdown]
# #9.In which year there was the hightest average rating

# %%
data.columns
# Out:
# Index(['rank', 'name', 'year', 'rating', 'genre', 'certificate', 'run_time',
#        'tagline', 'budget', 'box_office', 'casts', 'directors', 'writers',
#        'genre_list'],
#       dtype='object')

# %%
data.groupby('year')['rating'].mean().sort_values(ascending=False)
# Out:
# year
# 1972    9.2
# 1994    8.8
# 1974    8.6
# 1977    8.6
# 1991    8.6
#        ...
# 1934    8.1
# 1996    8.1
# 1967    8.1
# 1982    8.1
# 1949    8.1
# Name: rating, Length: 86, dtype: float64

# %% [markdown]
# #10.Display number of movies per year

# %%
data['year'].value_counts()
# Out:
# year
# 1995    8
# 2004    7
# 2009    6
# 1957    6
# 2003    6
#        ..
# 1941    1
# 1958    1
# 2022    1
# 1987    1
# 1934    1
# Name: count, Length: 86, dtype: int64

# %% [markdown]
# #11.Finding highest rating

# %%
data['rating'].max()
# Out:
# 9.3

# %%
data[data['rating'].max()==data['rating']]
# Out:
#    rank                      name  year  rating  genre certificate  run_time  \
# 0     1  The Shawshank Redemption  1994     9.3  Drama           R       NaN
#
#                                              tagline    budget  box_office  \
# 0  Fear can hold you prisoner. Hope can set you f...  25000000  28884504.0
#
#                                                casts       directors  \
# 0  Tim Robbins,Morgan Freeman,Bob Gunton,William ...  Frank Darabont
#
#                        writers genre_list
# 0  Stephen King,Frank Darabont    [Drama]

# %% [markdown]
# #12.Display top 10 highest rated movie titles and its directors

# %%
top10_len=data.nlargest(10,'rating')[['name','rating','directors']]\
.set_index('name')

# %%
top10_len
# Out:
#                                                    rating  \
# name
# The Shawshank Redemption                              9.3
# The Godfather                                         9.2
# The Dark Knight                                       9.0
# The Godfather Part II                                 9.0
# 12 Angry Men                                          9.0
# Schindler's List                                      9.0
# The Lord of the Rings: The Return of the King         9.0
# Pulp Fiction                                          8.9
# The Lord of the Rings: The Fellowship of the Ring     8.8
# The Good, the Bad and the Ugly                        8.8
#
#                                                               directors
# name
# The Shawshank Redemption                                 Frank Darabont
# The Godfather                                      Francis Ford Coppola
# The Dark Knight                                       Christopher Nolan
# The Godfather Part II                              Francis Ford Coppola
# 12 Angry Men                                               Sidney Lumet
# Schindler's List                                       Steven Spielberg
# The Lord of the Rings: The Return of the King             Peter Jackson
# Pulp Fiction                                          Quentin Tarantino
# The Lord of the Rings: The Fellowship of the Ring         Peter Jackson
# The Good, the Bad and the Ugly                             Sergio Leone

# %% [markdown]
# #13.Classify movies based on ratings [excellent,good and average]

# %%
def rating(rating):
  if rating>=9.0:
    return "Excellent"
  elif rating>=8.0:
    return "good"
  else:
    return "Average"

# %%
data['rating_cat']=data['rating'].apply(rating)

# %%
data.head(20)
# Out:
#     rank                                               name  year  rating  \
# 0      1                           The Shawshank Redemption  1994     9.3
# 1      2                                      The Godfather  1972     9.2
# 2      3                                    The Dark Knight  2008     9.0
# 3      4                              The Godfather Part II  1974     9.0
# 4      5                                       12 Angry Men  1957     9.0
# 5      6                                   Schindler's List  1993     9.0
# 6      7      The Lord of the Rings: The Return of the King  2003     9.0
# 7      8                                       Pulp Fiction  1994     8.9
# 8      9  The Lord of the Rings: The Fellowship of the Ring  2001     8.8
# 9     10                     The Good, the Bad and the Ugly  1966     8.8
# 10    11                                       Forrest Gump  1994     8.8
# 11    12                                         Fight Club  1999     8.8
# 12    13              The Lord of the Rings: The Two Towers  2002     8.8
# 13    14                                          Inception  2010     8.8
# 14    15     Star Wars: Episode V - The Empire Strikes Back  1980     8.7
# 15    16                                         The Matrix  1999     8.7
# 16    17                                         Goodfellas  1990     8.7
# 17    18                    One Flew Over the Cuckoo's Nest  1975     8.7
# 18    19                                              Se7en  1995     8.6
# 19    20                                      Seven Samurai  1954     8.6
#
#                        genre certificate  run_time  \
# 0                      Drama           R       NaN
# 1                Crime,Drama           R       NaN
# 2         Action,Crime,Drama       PG-13       NaN
# 3                Crime,Drama           R       NaN
# 4                Crime,Drama    Approved       NaN
# 5    Biography,Drama,History           R       NaN
# 6     Action,Adventure,Drama       PG-13       NaN
# 7                Crime,Drama           R       NaN
# 8     Action,Adventure,Drama       PG-13       NaN
# 9          Adventure,Western    Approved       NaN
# 10             Drama,Romance       PG-13       NaN
# 11                     Drama           R       NaN
# 12    Action,Adventure,Drama       PG-13       NaN
# 13   Action,Adventure,Sci-Fi       PG-13       NaN
# 14  Action,Adventure,Fantasy          PG       NaN
# 15             Action,Sci-Fi           R       NaN
# 16     Biography,Crime,Drama           R       NaN
# 17                     Drama         18+       NaN
# 18       Crime,Drama,Mystery           R       NaN
# 19              Action,Drama   Not Rated       NaN
#
#                                               tagline     budget  \
# 0   Fear can hold you prisoner. Hope can set you f...   25000000
# 1                          An offer you can't refuse.    6000000
# 2                                     Why So Serious?  185000000
# 3        All the power on earth can't change destiny.   13000000
# 4   Life Is In Their Hands -- Death Is On Their Mi...     350000
# 5     Whoever saves one life, saves the world entire.   22000000
# 6                     The eye of the enemy is moving.   94000000
# 7   Girls like me don't make invitations like this...    8000000
# 8                            The Legend Comes to Life   93000000
# 9   They formed an alliance of hate to steal a for...    1200000
# 10                           The story of a lifetime.   55000000
# 11  How much can you know about yourself if you've...   63000000
# 12                             A New Power Is Rising.   94000000
# 13                Your mind is the scene of the crime  160000000
# 14                         The Adventure Continues...   18000000
# 15                                     Free your mind   63000000
# 16  "As far back as I can remember, I've always wa...   25000000
# 17            If he's crazy, what does that make you?    3000000
# 18  Long is the way, and hard, that out of hell le...   33000000
# 19  Will Take Its Place With the Seven Greatest Fi...  125000000
#
#       box_office                                              casts  \
# 0   2.888450e+07  Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# 1            NaN  Marlon Brando,Al Pacino,James Caan,Diane Keato...
# 2   1.006234e+09  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...
# 3   4.796192e+07  Al Pacino,Robert De Niro,Robert Duvall,Diane K...
# 4   9.550000e+02  Henry Fonda,Lee J. Cobb,Martin Balsam,John Fie...
# 5   3.221612e+08  Liam Neeson,Ralph Fiennes,Ben Kingsley,Carolin...
# 6   1.146458e+09  Elijah Wood,Viggo Mortensen,Ian McKellen,Orlan...
# 7   2.139288e+08  John Travolta,Uma Thurman,Samuel L. Jackson,Br...
# 8   8.982044e+08  Elijah Wood,Ian McKellen,Orlando Bloom,Sean Be...
# 9   2.525389e+07  Clint Eastwood,Eli Wallach,Lee Van Cleef,Aldo ...
# 10  6.782265e+08  Tom Hanks,Robin Wright,Gary Sinise,Sally Field...
# 11  1.012097e+08  Brad Pitt,Edward Norton,Meat Loaf,Zach Grenier...
# 12  9.479443e+08  Elijah Wood,Ian McKellen,Viggo Mortensen,Orlan...
# 13  8.368481e+08  Leonardo DiCaprio,Joseph Gordon-Levitt,Elliot ...
# 14  5.383751e+08  Mark Hamill,Harrison Ford,Carrie Fisher,Billy ...
# 15  4.672227e+08  Keanu Reeves,Laurence Fishburne,Carrie-Anne Mo...
# 16  4.703678e+07  Robert De Niro,Ray Liotta,Joe Pesci,Lorraine B...
# 17  1.091148e+08  Jack Nicholson,Louise Fletcher,Michael Berryma...
# 18  3.273336e+08  Morgan Freeman,Brad Pitt,Kevin Spacey,Andrew K...
# 19  3.462580e+05  Toshirô Mifune,Takashi Shimura,Keiko Tsushima,...
#
#                          directors  \
# 0                   Frank Darabont
# 1             Francis Ford Coppola
# 2                Christopher Nolan
# 3             Francis Ford Coppola
# 4                     Sidney Lumet
# 5                 Steven Spielberg
# 6                    Peter Jackson
# 7                Quentin Tarantino
# 8                    Peter Jackson
# 9                     Sergio Leone
# 10                 Robert Zemeckis
# 11                   David Fincher
# 12                   Peter Jackson
# 13               Christopher Nolan
# 14                  Irvin Kershner
# 15  Lana Wachowski,Lilly Wachowski
# 16                 Martin Scorsese
# 17                    Milos Forman
# 18                   David Fincher
# 19                  Akira Kurosawa
#
#                                              writers  \
# 0                        Stephen King,Frank Darabont
# 1                    Mario Puzo,Francis Ford Coppola
# 2    Jonathan Nolan,Christopher Nolan,David S. Goyer
# 3                    Francis Ford Coppola,Mario Puzo
# 4                                      Reginald Rose
# 5                    Thomas Keneally,Steven Zaillian
# 6          J.R.R. Tolkien,Fran Walsh,Philippa Boyens
# 7                      Quentin Tarantino,Roger Avary
# 8          J.R.R. Tolkien,Fran Walsh,Philippa Boyens
# 9   Luciano Vincenzoni,Sergio Leone,Agenore Incrocci
# 10                           Winston Groom,Eric Roth
# 11                          Chuck Palahniuk,Jim Uhls
# 12         J.R.R. Tolkien,Fran Walsh,Philippa Boyens
# 13                                 Christopher Nolan
# 14       Leigh Brackett,Lawrence Kasdan,George Lucas
# 15                    Lilly Wachowski,Lana Wachowski
# 16                  Nicholas Pileggi,Martin Scorsese
# 17              Lawrence Hauben,Bo Goldman,Ken Kesey
# 18                               Andrew Kevin Walker
# 19      Akira Kurosawa,Shinobu Hashimoto,Hideo Oguni
#
#                       genre_list rating_cat
# 0                        [Drama]  Excellent
# 1                 [Crime, Drama]  Excellent
# 2         [Action, Crime, Drama]  Excellent
# 3                 [Crime, Drama]  Excellent
# 4                 [Crime, Drama]  Excellent
# 5    [Biography, Drama, History]  Excellent
# 6     [Action, Adventure, Drama]  Excellent
# 7                 [Crime, Drama]       good
# 8     [Action, Adventure, Drama]       good
# 9           [Adventure, Western]       good
# 10              [Drama, Romance]       good
# 11                       [Drama]       good
# 12    [Action, Adventure, Drama]       good
# 13   [Action, Adventure, Sci-Fi]       good
# 14  [Action, Adventure, Fantasy]       good
# 15              [Action, Sci-Fi]       good
# 16     [Biography, Crime, Drama]       good
# 17                       [Drama]       good
# 18       [Crime, Drama, Mystery]       good
# 19               [Action, Drama]       good

# %% [markdown]
# #14.Count number of action movies

# %%
genre_of_interest = 'Action'
data['genre_list'] = data['genre'].str.split(',')
action_movies = data[data['genre_list'].apply(lambda x: genre_of_interest in x)]
num_movies = len(action_movies)
print("Number of movies in the '{}' genre: {}".format(genre_of_interest, num_movies))
# Out:
# Number of movies in the 'Action' genre: 50

# %% [markdown]
# #15.NUMPY operations

# %%
mean_rating = np.mean(data['rating'])
median_rating = np.median(data['rating'])
std_dev_rating = np.std(data['rating'])
print("Mean Rating:", mean_rating)
print("Median Rating:", median_rating)
print("Standard Deviation of Ratings:", std_dev_rating)
# Out:
# Mean Rating: 8.3072
# Median Rating: 8.2
# Standard Deviation of Ratings: 0.22862230862275906

# %% [markdown]
# #MATPLOTLIB

# %% [markdown]
# #Histogram - Distribution of movie ratings

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['rating'], bins=20, edgecolor='black')
plt.title('Distribution of Movie Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #Distribution of movie years in the IMDb Top 250 list

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['year'], bins=20, edgecolor='black')
plt.title('Distribution of Movie Years')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #Bar Plot - Comparison of movie genres

# %%
plt.figure(figsize=(10, 6))
genre_counts = data['genre'].value_counts().head(10)
genre_counts.plot(kind='bar', color='skyblue')
plt.title('Top 10 Movie Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45)
plt.show()

# %%
data['box_office'] = pd.to_numeric(data['box_office'], errors='coerce')
print(data.dtypes)
# Out:
# rank             int64
# name            object
# year             int64
# rating         float64
# genre           object
# certificate     object
# run_time        object
# tagline         object
# budget          object
# box_office     float64
# casts           object
# directors       object
# writers         object
# dtype: object

# %% [markdown]
# #Scatter Plot - Relationship between ratings and box office earnings

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data['rating'], data['box_office'], color='orange', alpha=0.5)
plt.title('Rating vs. Box Office Earnings')
plt.xlabel('Rating')
plt.ylabel('Box Office Earnings')
plt.show()

# %%
genre_of_interest = 'Action'
data['genre_list'] = data['genre'].str.split(',')
action_movies = data[data['genre_list'].apply(lambda x: genre_of_interest in x)]
num_movies = len(action_movies)
print("Number of movies in the '{}' genre: {}".format(genre_of_interest, num_movies))
# Out:
# Number of movies in the 'Action' genre: 50

# %%
genre_of_interest = 'Drama'
data['genre_list'] = data['genre'].str.split(',')
action_movies = data[data['genre_list'].apply(lambda x: genre_of_interest in x)]
num_movies = len(action_movies)
print("Number of movies in the '{}' genre: {}".format(genre_of_interest, num_movies))
# Out:
# Number of movies in the 'Drama' genre: 177

# %%
genre_of_interest = 'Crime'
data['genre_list'] = data['genre'].str.split(',')
action_movies = data[data['genre_list'].apply(lambda x: genre_of_interest in x)]
num_movies = len(action_movies)
print("Number of movies in the '{}' genre: {}".format(genre_of_interest, num_movies))
# Out:
# Number of movies in the 'Crime' genre: 51

# %%
genre_of_interest = 'Thriller'
data['genre_list'] = data['genre'].str.split(',')
action_movies = data[data['genre_list'].apply(lambda x: genre_of_interest in x)]
num_movies = len(action_movies)
print("Number of movies in the '{}' genre: {}".format(genre_of_interest, num_movies))
# Out:
# Number of movies in the 'Thriller' genre: 30

# %%
genre_of_interest = 'War'
data['genre_list'] = data['genre'].str.split(',')
action_movies = data[data['genre_list'].apply(lambda x: genre_of_interest in x)]
num_movies = len(action_movies)
print("Number of movies in the '{}' genre: {}".format(genre_of_interest, num_movies))
# Out:
# Number of movies in the 'War' genre: 23

# %%
genre_of_interest = 'Romance'
data['genre_list'] = data['genre'].str.split(',')
action_movies = data[data['genre_list'].apply(lambda x: genre_of_interest in x)]
num_movies = len(action_movies)
print("Number of movies in the '{}' genre: {}".format(genre_of_interest, num_movies))
# Out:
# Number of movies in the 'Romance' genre: 23

# %%
genre_of_interest = 'Adventure'
data['genre_list'] = data['genre'].str.split(',')
action_movies = data[data['genre_list'].apply(lambda x: genre_of_interest in x)]
num_movies = len(action_movies)
print("Number of movies in the '{}' genre: {}".format(genre_of_interest, num_movies))
# Out:
# Number of movies in the 'Adventure' genre: 60

# %%
genre_of_interest = 'Comedy'
data['genre_list'] = data['genre'].str.split(',')
action_movies = data[data['genre_list'].apply(lambda x: genre_of_interest in x)]
num_movies = len(action_movies)
print("Number of movies in the '{}' genre: {}".format(genre_of_interest, num_movies))
# Out:
# Number of movies in the 'Comedy' genre: 45

# %%
genre_of_interest = 'Horror'
data['genre_list'] = data['genre'].str.split(',')
action_movies = data[data['genre_list'].apply(lambda x: genre_of_interest in x)]
num_movies = len(action_movies)
print("Number of movies in the '{}' genre: {}".format(genre_of_interest, num_movies))
# Out:
# Number of movies in the 'Horror' genre: 5

# %% [markdown]
# #**GENRE DYNAMIC ANALYSIS** : Calculating the no.of movies from each genre and visualizing the genre analysis using a PieChart

# %%
import matplotlib.pyplot as plt
genres = ['Action', 'Comedy', 'Horror', 'Thriller', 'Drama', 'Romance', 'War', 'Adventure']
genre_counts = [50, 5, 23, 30, 177, 23, 23, 60]
print(len(genres), len(genre_counts))
plt.figure(figsize=(8, 8))
plt.pie(genre_counts, labels=genres, autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightblue', 'lightskyblue', 'lightyellow', 'lightgreen', 'pink', 'cyan', 'lavender'])
plt.title('Distribution of Movie Genres')
plt.show()
# Out:
# 8 8

# %% [markdown]
# #Line Plot - Trend of movie ratings over the years

# %%
plt.figure(figsize=(10, 6))
ratings_over_years = data.groupby('year')['rating'].mean()
ratings_over_years.plot(color='green')
plt.title('Average Movie Rating Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.show()
